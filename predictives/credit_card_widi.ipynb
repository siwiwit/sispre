# %% [markdown]
#  Global Variables

# %%
import os
import sys
import unittest
import urllib.error
import urllib.parse
import urllib.request
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pandas_log as pl
import seaborn as sns
from IPython import get_ipython
from pandas import DataFrame
import logging

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# %matplotlib inline
# get_ipython().magic(u'matplotlib inline')
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', 20)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.width', 1000)

# %%
class CreditCardPredictive:

    data_dir = 'data'
    file_name = 'credit_card_default.csv'
    dataFrame = DataFrame()

    numerical_features = []
    categorical_features = []
# %%

    def __init__(self):
        logging.debug('===init start')
        pass
        logging.debug('===init end')

    def data_read_csv(self, file_url):
        logging.debug('===func_read_data_csv start')
        logging.debug(' fileurl : %s', file_url)
        self.dataFrame = pd.read_csv(file_url)
        logging.debug('===func_read_data_csv end')

    def data_analysis_descriptive(self):
        logging.debug('===func_descriptif_data_analysis start')
        self.data_analysis_tabular()
        self.data_analysis_statistical()
        self.data_analysis_graphical()
        logging.debug('===func_descriptif_data_analysis end')

    def data_analysis_tabular(self):
        logging.debug('===func_tabular_data_analysis start')
        logging.debug('columns = %s', self.dataFrame.columns)
        logging.debug('===func_tabular_data_analysis end')

    def data_analysis_graphical(self):
        logging.debug('===func_graphical_data_analysis start')
        if logger.getEffectiveLevel()==logging.DEBUG:
            self.dataFrame.hist()
            plt.show()
            self.dataFrame.plot()
            plt.show()
            self.dataFrame.boxplot()
            plt.show()
        else:
            logging.debug('===passing')
        logging.debug('===func_graphical_data_analysis end')

    def data_analysis_statistical(self):
        logging.debug('===func_statistical_data_analysis start')
        logging.debug('===func_statistical_data_analysis end')

    def data_analysis_explanatory(self):
        logging.debug('===func_explanatory_data_analysis start')
        for x in self.numerical_features:
            self.data_preparation_encode_feature_numerical(x)
        logging.debug('===func_explanatory_data_analysis end')

    def data_cleansing(self):
        logging.debug('===func_data_cleansing start')
        logging.debug('===func_data_cleansing end')

    def data_preparation_encode_feature_categorical(self):
        logging.debug('===func_data_encode_categorical_feature start')
        logging.debug('===func_data_encode_categorical_feature end')

    def data_preparation(self):
        logging.debug('===func_data_preparation start')
        self.data_cleansing()
        self.data_preparation_encode_feature_categorical()
        logging.debug('===func_data_preparation end')

    def data_preparation_imputal(self):
        logging.debug('===data_preparation_imputal start')
        logging.debug('===data_preparation_imputal end')

    def data_preparation_encode_feature_numerical(self, feature_name, bins=30, edgecolor='k', **kwargs):
        logging.debug('===desc_num_feature start')
        logging.debug('===desc_num_feature end')

    model_01 = 0.0

    def create_model_01(self):
        self.model_01 = np.mean(
            self.dataFrame['price']/self.dataFrame['carat'])

    def first_ml_model(self, carat):
        return self.model_01 * carat

    def train_test_split(self):
        logging.debug('===train_test_split start')
        logging.debug('===train_test_split end')

def is_running_from_ipython():
    from IPython import get_ipython
    return get_ipython() is not None

def main():
    # get_ipython().run_line_magic('matplotlib', 'inline')
    data_dir = 'data'
    file_name = 'credit_card_default.csv'
    file_url = ''
    if not is_running_from_ipython():
        abspath = os.path.abspath('.')
        file_url = 'file://'+abspath+os.path.sep+data_dir+os.path.sep+file_name
    else:
        file_url = os.path.join('../',data_dir, file_name)
    # logging.debug('abspath %s', abspath)
    dp = CreditCardPredictive()
    dp.data_read_csv(file_url)
    dp.data_analysis_descriptive()
    dp.data_analysis_explanatory()
    dp.data_preparation()
    data = dp.dataFrame


if __name__ == "__main__":
    main()
